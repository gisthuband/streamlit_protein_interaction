# %%
import streamlit as st
import pandas as pd
import math
from pathlib import Path
from sklearn.model_selection import GridSearchCV
from sklearn import preprocessing
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc

# %%
# Set the title and favicon that appear in the Browser's tab bar.
st.set_page_config(
    page_title='Protein Interaction Predictor',
    page_icon=':earth_americas:', # This is an emoji shortcode. Could be a URL too.
)

# -----------------------------------------------------------------------------
# Declare some useful functions.

@st.cache_data
def get_protein_data():
    """Grab GDP data from a CSV file.

    This uses caching to avoid having to read the file every time. If we were
    reading from an HTTP endpoint instead of a file, it's a good idea to set
    a maximum age to the cache with the TTL argument: @st.cache_data(ttl='1d')
    """

    # Instead of a CSV on disk, you could read from an HTTP endpoint here too.
    DATA_FILENAME = Path(__file__).parent/'data/condensed_feature_engineered.csv'
    protein_df = pd.read_csv(DATA_FILENAME)


    

    return protein_df

usable_df = get_protein_data()

st.write(usable_df.head())
# -----------------------------------------------------------------------------
# Draw the actual page

# Set the title that appears at the top of the page.
'''
# :earth_americas: Protein Interaction Predictor (PIP)

This is my protein interaction predictor.  Just input protein 1's sequence and protein 2's sequence, and click 'submit'.

'''

# Add some spacing
''
''


user_text1 = st.text_area('input protein sequence 1')
st.write(user_text1)

user_text2 = st.text_area('input protein sequence 2')
st.write(user_text2)

seqs = [user_text1, user_text2]

''
''

def seq_features(seqs):
    
    #structure = {'protein_1_seq':'p', 'protein_1_len':'p', '1_phobic_count':'p', '1_philic_count':'p', '1_basic_count': 'p', '1_acidic_count': 'p', '1_aromatic_count':'p', '1_sulfur_count': 'p', 'protein_2_seq':'p', 'protein_2_len':'p', '2_phobic_count':'p', '2_philic_count':'p', '2_basic_count': 'p', '2_acidic_count': 'p', '2_aromatic_count':'p', '2_sulfur_count': 'p'}
    #new_df = pd.DataFrame(data=structure, index=[0])
    
        
    p1_list = []
    p2_list = []
        
    for i in range(2):
            
        amino_acids = ['A','C','D','E','F','G','H','I','K','L','M','N','P','Q', 'R','S','T','V','W','Y']
    
        ind_counts = {}
        for a in amino_acids:
            ind_counts[a] = 0

        phobic = {'A':0, 'F':0, 'G':0, 'I':0, 'L':0, 'M':0, 'P':0, 'V':0, 'W':0, 'Y':0, 'phobic_total':0}
        philic = {'C':0, 'D':0, 'E':0, 'H':0, 'K':0, 'N':0, 'Q':0, 'R':0, 'S':0, 'T':0, 'philic_total':0}
        basic = {'H':0, 'K':0, 'R':0, 'basic_total':0}
        acidic = {'D':0, 'E':0, 'acidic_total':0}
        aromatic = {'F':0, 'H':0, 'W':0, 'Y':0, 'aromatic_total':0}
        sulfur = {'C':0 , 'M':0, 'sulfur_total':0}
            
            
        seq = seqs[i]
        seq_split = [y for y in seq]
        seq_len = len(seq_split)
            
        for z in seq_split:
                
            if z in ind_counts:
                ind_counts[z] += 1
                    
            if z in phobic:
                phobic[z] += 1
                phobic['phobic_total'] += 1
                    
            if z in philic:
                philic[z] += 1
                philic['philic_total'] += 1
                    
            if z in basic:
                basic[z] += 1
                basic['basic_total'] += 1
                    
            if z in acidic:
                acidic[z] += 1
                acidic['acidic_total'] += 1
                    
            if z in aromatic:
                aromatic[z] += 1
                aromatic['aromatic_total'] += 1
                    
            if z in sulfur:
                sulfur[z] += 1
                sulfur['sulfur_total'] += 1
                    
                    
        if i == 0:
                
            p1_list = [seq, seq_len, phobic['phobic_total'], philic['philic_total'], basic['basic_total'], acidic['acidic_total'], aromatic['aromatic_total'], sulfur['sulfur_total']]
                
        elif i != 0:
                
            p2_list = [seq, seq_len, phobic['phobic_total'], philic['philic_total'], basic['basic_total'], acidic['acidic_total'], aromatic['aromatic_total'], sulfur['sulfur_total']]
                
    p3_list = p1_list + p2_list
        
        
    return p3_list


merged = seq_features(seqs)

''
''
st.write(merged)
# Out:
# 2025-01-24 02:15:16.760 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2025-01-24 02:15:16.853
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /opt/anaconda3/lib/python3.11/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2025-01-24 02:15:16.853 No runtime found, using MemoryCacheStorageManager
# ---------------------------------------------------------------------------
# CacheStorageKeyNotFoundError              Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.11/site-packages/streamlit/runtime/caching/storage/in_memory_cache_storage_wrapper.py:87, in InMemoryCacheStorageWrapper.get(self, key)
#      86 try:
# ---> 87     entry_bytes = self._read_from_mem_cache(key)
#      88 except CacheStorageKeyNotFoundError:
#
# File /opt/anaconda3/lib/python3.11/site-packages/streamlit/runtime/caching/storage/in_memory_cache_storage_wrapper.py:137, in InMemoryCacheStorageWrapper._read_from_mem_cache(self, key)
#     136 _LOGGER.debug("Memory cache MISS: %s", key)
# --> 137 raise CacheStorageKeyNotFoundError("Key not found in mem cache")
#
# CacheStorageKeyNotFoundError: Key not found in mem cache
#
# During handling of the above exception, another exception occurred:
#
# CacheStorageKeyNotFoundError              Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.11/site-packages/streamlit/runtime/caching/cache_data_api.py:634, in DataCache.read_result(self, key)
#     633 try:
# --> 634     pickled_entry = self.storage.get(key)
#     635 except CacheStorageKeyNotFoundError as e:
#
# File /opt/anaconda3/lib/python3.11/site-packages/streamlit/runtime/caching/storage/in_memory_cache_storage_wrapper.py:89, in InMemoryCacheStorageWrapper.get(self, key)
#      88 except CacheStorageKeyNotFoundError:
# ---> 89     entry_bytes = self._persist_storage.get(key)
#      90     self._write_to_mem_cache(key, entry_bytes)
#
# File /opt/anaconda3/lib/python3.11/site-packages/streamlit/runtime/caching/storage/dummy_cache_storage.py:48, in DummyCacheStorage.get(self, key)
#      44 """
#      45 Dummy gets the value for a given key,
#      46 always raises an CacheStorageKeyNotFoundError
#      47 """
# ---> 48 raise CacheStorageKeyNotFoundError("Key not found in dummy cache")
#
# CacheStorageKeyNotFoundError: Key not found in dummy cache
#
# The above exception was the direct cause of the following exception:
#
# CacheKeyNotFoundError                     Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.11/site-packages/streamlit/runtime/caching/cache_utils.py:264, in CachedFunc._get_or_create_cached_value(self, func_args, func_kwargs)
#     263 try:
# --> 264     cached_result = cache.read_result(value_key)
#     265     return self._handle_cache_hit(cached_result)
#
# File /opt/anaconda3/lib/python3.11/site-packages/streamlit/runtime/caching/cache_data_api.py:636, in DataCache.read_result(self, key)
#     635 except CacheStorageKeyNotFoundError as e:
# --> 636     raise CacheKeyNotFoundError(str(e)) from e
#     637 except CacheStorageError as e:
#
# CacheKeyNotFoundError: Key not found in dummy cache
#
# During handling of the above exception, another exception occurred:
#
# CacheStorageKeyNotFoundError              Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.11/site-packages/streamlit/runtime/caching/storage/in_memory_cache_storage_wrapper.py:87, in InMemoryCacheStorageWrapper.get(self, key)
#      86 try:
# ---> 87     entry_bytes = self._read_from_mem_cache(key)
#      88 except CacheStorageKeyNotFoundError:
#
# File /opt/anaconda3/lib/python3.11/site-packages/streamlit/runtime/caching/storage/in_memory_cache_storage_wrapper.py:137, in InMemoryCacheStorageWrapper._read_from_mem_cache(self, key)
#     136 _LOGGER.debug("Memory cache MISS: %s", key)
# --> 137 raise CacheStorageKeyNotFoundError("Key not found in mem cache")
#
# CacheStorageKeyNotFoundError: Key not found in mem cache
#
# During handling of the above exception, another exception occurred:
#
# CacheStorageKeyNotFoundError              Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.11/site-packages/streamlit/runtime/caching/cache_data_api.py:634, in DataCache.read_result(self, key)
#     633 try:
# --> 634     pickled_entry = self.storage.get(key)
#     635 except CacheStorageKeyNotFoundError as e:
#
# File /opt/anaconda3/lib/python3.11/site-packages/streamlit/runtime/caching/storage/in_memory_cache_storage_wrapper.py:89, in InMemoryCacheStorageWrapper.get(self, key)
#      88 except CacheStorageKeyNotFoundError:
# ---> 89     entry_bytes = self._persist_storage.get(key)
#      90     self._write_to_mem_cache(key, entry_bytes)
#
# File /opt/anaconda3/lib/python3.11/site-packages/streamlit/runtime/caching/storage/dummy_cache_storage.py:48, in DummyCacheStorage.get(self, key)
#      44 """
#      45 Dummy gets the value for a given key,
#      46 always raises an CacheStorageKeyNotFoundError
#      47 """
# ---> 48 raise CacheStorageKeyNotFoundError("Key not found in dummy cache")
#
# CacheStorageKeyNotFoundError: Key not found in dummy cache
#
# The above exception was the direct cause of the following exception:
#
# CacheKeyNotFoundError                     Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.11/site-packages/streamlit/runtime/caching/cache_utils.py:312, in CachedFunc._handle_cache_miss(self, cache, value_key, func_args, func_kwargs)
#     311 try:
# --> 312     cached_result = cache.read_result(value_key)
#     313     # Another thread computed the value before us. Early exit!
#
# File /opt/anaconda3/lib/python3.11/site-packages/streamlit/runtime/caching/cache_data_api.py:636, in DataCache.read_result(self, key)
#     635 except CacheStorageKeyNotFoundError as e:
# --> 636     raise CacheKeyNotFoundError(str(e)) from e
#     637 except CacheStorageError as e:
#
# CacheKeyNotFoundError: Key not found in dummy cache
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 28
#      21     protein_df = pd.read_csv(DATA_FILENAME)
#      26     return protein_df
# ---> 28 usable_df = get_protein_data()
#      30 st.write(usable_df.head())
#      31 # -----------------------------------------------------------------------------
#      32 # Draw the actual page
#      33
#      34 # Set the title that appears at the top of the page.
#
# File /opt/anaconda3/lib/python3.11/site-packages/streamlit/runtime/caching/cache_utils.py:212, in make_cached_func_wrapper.<locals>.wrapper(*args, **kwargs)
#     210 @functools.wraps(info.func)
#     211 def wrapper(*args, **kwargs):
# --> 212     return cached_func(*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.11/site-packages/streamlit/runtime/caching/cache_utils.py:241, in CachedFunc.__call__(self, *args, **kwargs)
#     239 if self._info.show_spinner or isinstance(self._info.show_spinner, str):
#     240     with spinner(message, cache=True):
# --> 241         return self._get_or_create_cached_value(args, kwargs)
#     242 else:
#     243     return self._get_or_create_cached_value(args, kwargs)
#
# File /opt/anaconda3/lib/python3.11/site-packages/streamlit/runtime/caching/cache_utils.py:267, in CachedFunc._get_or_create_cached_value(self, func_args, func_kwargs)
#     265     return self._handle_cache_hit(cached_result)
#     266 except CacheKeyNotFoundError:
# --> 267     return self._handle_cache_miss(cache, value_key, func_args, func_kwargs)
#
# File /opt/anaconda3/lib/python3.11/site-packages/streamlit/runtime/caching/cache_utils.py:321, in CachedFunc._handle_cache_miss(self, cache, value_key, func_args, func_kwargs)
#     316 except CacheKeyNotFoundError:
#     317     # We acquired the lock before any other thread. Compute the value!
#     318     with self._info.cached_message_replay_ctx.calling_cached_function(
#     319         self._info.func, self._info.allow_widgets
#     320     ):
# --> 321         computed_value = self._info.func(*func_args, **func_kwargs)
#     323     # We've computed our value, and now we need to write it back to the cache
#     324     # along with any "replay messages" that were generated during value computation.
#     325     messages = self._info.cached_message_replay_ctx._most_recent_messages
#
# Cell In[4], line 20, in get_protein_data()
#      12 """Grab GDP data from a CSV file.
#      13
#      14 This uses caching to avoid having to read the file every time. If we were
#      15 reading from an HTTP endpoint instead of a file, it's a good idea to set
#      16 a maximum age to the cache with the TTL argument: @st.cache_data(ttl='1d')
#      17 """
#      19 # Instead of a CSV on disk, you could read from an HTTP endpoint here too.
# ---> 20 DATA_FILENAME = Path(__file__).parent/'data/condensed_feature_engineered.csv'
#      21 protein_df = pd.read_csv(DATA_FILENAME)
#      26 return protein_df
#
# NameError: name '__file__' is not defined
